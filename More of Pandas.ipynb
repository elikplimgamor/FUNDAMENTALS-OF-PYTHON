# %%
#Groupby 
# split data into groups bas on some criteria 
# Applys a function to groups independently 
# Conbines the result into a dataframes

# %%
#The Groupby Object 

import pandas as pd

# %%
oo=pd.read_csv("athlete_events.csv")

# %%
oo.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
oo.groupby("Year")

# %%
type(oo.groupby("Year"))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(oo.groupby("Year"))
# Out:
# [(1896,
#               ID                                Name Sex   Age  Height  Weight  \
#   3079      1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
#   3080      1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
#   3081      1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
#   3082      1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
#   7348      4113                  Anastasios Andreou   M   NaN     NaN     NaN
#   ...        ...                                 ...  ..   ...     ...     ...
#   270473  135285                     Khristos Zoumis   M   NaN     NaN     NaN
#   270914  135481         Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
#   270915  135481         Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
#   270916  135481         Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
#   270917  135481         Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
#
# ...

# %%
#iterating through a group

# %%
for group_key,group_value in oo.groupby("Year"):
    print(group_key)
    print(group_value)
# Out:
# 1896
#             ID                                Name Sex   Age  Height  Weight  \
# 3079      1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
# 3080      1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
# 3081      1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
# 3082      1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
# 7348      4113                  Anastasios Andreou   M   NaN     NaN     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 270473  135285                     Khristos Zoumis   M   NaN     NaN     NaN
# 270914  135481         Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270915  135481         Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270916  135481         Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270917  135481         Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
#
# ...

# %% [markdown]
# ### Challenges 1

# %% [markdown]
# List our Olympics Dataframe
# list only the NOC columns using both the [" "] and dot notation
# Name the type of object for the above
# list the edition, city name and medal column
# what is the type of the object

# %%
import pandas as pd

# %%
oo = pd.read_csv("athlete_events.csv")
oo.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
oo
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
oo["NOC"]
# Out:
# 0         CHN
# 1         CHN
# 2         DEN
# 3         DEN
# 4         NED
#          ...
# 271111    POL
# 271112    POL
# 271113    POL
# 271114    POL
# 271115    POL
# Name: NOC, Length: 271116, dtype: object

# %%
oo.NOC
# Out:
# 0         CHN
# 1         CHN
# 2         DEN
# 3         DEN
# 4         NED
#          ...
# 271111    POL
# 271112    POL
# 271113    POL
# 271114    POL
# 271115    POL
# Name: NOC, Length: 271116, dtype: object

# %%
type(oo.NOC)
# Out:
# pandas.core.series.Series

# %%
oo[["Name","City","Year","Medal"]]
# Out:
#                             Name            City  Year Medal
# 0                      A Dijiang       Barcelona  1992   NaN
# 1                       A Lamusi          London  2012   NaN
# 2            Gunnar Nielsen Aaby       Antwerpen  1920   NaN
# 3           Edgar Lindenau Aabye           Paris  1900  Gold
# 4       Christine Jacoba Aaftink         Calgary  1988   NaN
# ...                          ...             ...   ...   ...
# 271111                Andrzej ya       Innsbruck  1976   NaN
# 271112                  Piotr ya           Sochi  2014   NaN
# 271113                  Piotr ya           Sochi  2014   NaN
# 271114        Tomasz Ireneusz ya          Nagano  1998   NaN
# 271115        Tomasz Ireneusz ya  Salt Lake City  2002   NaN
#
# [271116 rows x 4 columns]

# %% [markdown]
# ### Challenges 3

# %% [markdown]
# In which event did Piotr ya win a medal
# which country has won the most men's gold medal in single badminton over the years
# Display the male gold medal winner for the 100m track and field sprint event over the years
#
# List the results starting with most recent
#
# show the olympic city , edition, athlete and the country  they represented

# %%
# In which event did Jesse Owens win a medal

# %%
py=oo[oo.Name == "Piotr ya"]

# %%
py.Event.value_counts()
# Out:
# Ski Jumping Men's Large Hill, Individual    1
# Ski Jumping Men's Large Hill, Team          1
# Name: Event, dtype: int64

# %%
#which country has won the most men's gold medal in single badminton over the years

# %%
gbm = oo[(oo.Medal == "Gold") & (oo.Sex == "M") & (oo.Sport == "Badminton")]

# %%
gbm.sort_values(by="Name")
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 31409    16152   Alexander Alan Budikusuma Wiratama   M  24.0   178.0    71.0
# 33538    17299                              Cai Yun   M  32.0   181.0    68.0
# 260443  130336                        Candra Wijaya   M  24.0   173.0    67.0
# 39337    20238                            Chen Long   M  27.0   188.0    81.0
# 73578    37396                           Fu Haifeng   M  28.0   181.0    78.0
# 73579    37396                           Fu Haifeng   M  32.0   181.0    78.0
# 87648    44426                          Ha Tae-Gwon   M  29.0   187.0    87.0
# 216957  108952                      Hendra Setiawan   M  23.0   183.0    82.0
# 108331   54755                           Ji Xinpeng   M  22.0   181.0    70.0
# 118307   59848                         Kim Dong-Mun   M  20.0   184.0    74.0
# 118312   59848                         Kim Dong-Mun   M  28.0   184.0    74.0
# ...

# %%
#Which 3 countries have won the most medals in recent years

# %%
rec = oo[oo.Year>= 1984]
rec.NOC.value_counts().head(3)
# Out:
# USA    9096
# CAN    5960
# GER    5688
# Name: NOC, dtype: int64

# %%
#Display the male gold medal winner for the 100m track and field sprint event over the years

# %%
gmh = oo[(oo.Sex == "M") & (oo.Medal == "Gold") & (oo.Event == )]
